# %%
import pandas as pd

hourly = pd.read_parquet("../data/gold/hourly_features_20251208.parquet")
daily  = pd.read_parquet("../data/gold/daily_aggregates_20251208.parquet")

hourly.head()
# Out:
#                        time  temperature_2m  relative_humidity_2m  \
# 0 2025-12-01 00:00:00+00:00             6.5                    93
# 1 2025-12-01 01:00:00+00:00             5.4                    89
# 2 2025-12-01 02:00:00+00:00             5.3                    93
# 3 2025-12-01 03:00:00+00:00             4.5                    91
# 4 2025-12-01 04:00:00+00:00             3.6                    87
#
#    dew_point_2m  precipitation_probability  precipitation  cloud_cover  \
# 0           5.4                          0            0.0           82
# 1           3.8                          0            0.0          100
# 2           4.3                          0            0.0          100
# 3           3.2                          0            0.0           48
# 4           1.7                          0            0.0           97
#
#    surface_pressure  wind_speed_10m  wind_gusts_10m  ...  wind_lag_1h  \
# ...
