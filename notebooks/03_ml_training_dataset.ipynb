# %%
from pathlib import Path
import pandas as pd

gold_path = Path("../../data/gold")
latest = sorted(gold_path.glob("hourly_features_*.parquet"))[-1]
df = pd.read_parquet(latest)

df.head()

# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = (
    SparkSession.builder
    .appName("weather_ml_training")
    .getOrCreate()
)

# Load the same file into Spark
df_spark = spark.read.parquet(str(latest))

df_spark.show(5)
df_spark.printSchema()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyspark.sql import SparkSession
#       3 # Create Spark session
#       4 spark = (
#       5     SparkSession.builder
#       6     .appName("weather_ml_training")
#       7     .getOrCreate()
#       8 )
#
# ModuleNotFoundError: No module named 'pyspark'
